# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('kingCountyHouseData-1.csv')
x = data.iloc[:, :-1].values
y = data.iloc[:, -1].values
print(x)
# Out:
# [[7129300520 '20141013T000000' 221900.0 ... 47.5112 -122.257 1340]
#  [6414100192 '20141209T000000' 538000.0 ... 47.721 -122.319 1690]
#  [5631500400 '20150225T000000' 180000.0 ... 47.7379 -122.233 2720]
#  ...
#  [1523300141 '20140623T000000' 402101.0 ... 47.5944 -122.299 1020]
#  [291310100 '20150116T000000' 400000.0 ... 47.5345 -122.069 1410]
#  [1523300157 '20141015T000000' 325000.0 ... 47.5941 -122.299 1020]]

# %% [markdown]
# A. Missing Data

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# B. Head and tail of the dataset

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %% [markdown]
# C. Establish a relationship between water view flats with the prices

# %%
column_1 = data["price"]
column_2 = data["waterfront"]
correlation = column_1.corr(column_2)
correlation
# Out:
# 0.26636943403060226

# %% [markdown]
# D. histogram or heatmap

# %%
import seaborn as sns
corr = data.corr()

plt.figure(figsize = (15,10))

sns.heatmap(corr, center = 0, annot = True, cmap = 'coolwarm')

plt.title('Correlation Heatmap')

plt.show();

# %%
data.hist(figsize  = [15, 15],bins=30) 

plt.show();
